# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
a = [1,2,3]

# %%
plt.plot(a,a)

# %%
from matplotlib import rcParams

# %%
rcParams['font.family']='serif'

# %%
rcParams['font.serif']='Comic Sans MS'

# %%
plt.plot(a,a)
